# %% [markdown]
# ![outliers_ma.png](data:image/png;base64,...)

# %% [markdown]
# ## Importante
# Cada vez que desarrolles un ejercicio registra tu tiempo de resolución, a este se le designa **TR** y está asociado a un **RTE** (**R**ango de **T**iempo **E**sperado), en caso que tú tiempo este sobre el máximo **RTE** no te desanimes `el dasafío es primero resolver, luego mejorar tus tiempos.`

# %% [markdown]
# ---
#
#
# ## Cuadernillo M11 - Integración 01 (1- 5) RTE [20 - 40]min
#
# Has llegado al cudernillo de intergración 01, lo que significa que puedes transformar un diagrama a código.
#
# ![simbologia_df.JPG](data:image/jpeg;base64,...)

# %% [markdown]
# ### Ejemplo_1: de transformación de DF a Código Python
#
# Indicar qué hace el Diagrama en un comentario y luego resolver en código Python
#
# ![CM11_DF_EJEMPLO.JPG](data:image/jpeg;base64,...)

# %%
# Ejemplo_1: Suma dos números y muestra el resultado
num1 = int(input('Ingrese un número: '))
num2 = int(input('Ingrese un otro número: '))
Res = num1 + num2
print(Res)

# %%
# Bien, manos a la obra inicia tu cuadernillo registrando hora inicio, sólo en comentario.

# %% [markdown]
# #### M11.1 Indicar qué hace el Diagrama en un comentario y luego resolver en código Python.
#
# ![cm11_df_01.JPG](data:image/jpeg;base64,...)

# %%
#Desarrollo solución M11.1

# %% [markdown]
# #### M11.2 Indicar qué hace el Diagrama en un comentario y luego resolver en código Python.
#
# ![cm11_df_02.JPG](data:image/jpeg;base64,...)

# %%
#Desarrollo solución M11.2

# %% [markdown]
# #### M11.3 Indicar qué hace el Diagrama en un comentario y luego resolver en código Python.
#
# ![cm11_df_03.JPG](data:image/jpeg;base64,...)

# %%
#Desarrollo solución M11.3

# %% [markdown]
# #### M11.4 Indicar qué hace el Diagrama en un comentario y luego resolver en código Python.
#
# ![cm11_df_04.JPG](data:image/jpeg;base64,...)

# %%
#Desarrollo solución M11.4

# %% [markdown]
# #### M11.5 Indicar qué hace el Diagrama en un comentario y luego resolver en código Python.
#
# ![cm11_df_05.JPG](data:image/jpeg;base64,...)

# %%
#Desarrollo solución M11.5

# %%
#¡¡¡Felicitaciones!!!, terminaste tu cuadernillo.
# Por favor registra hora Final y tu tiempo de ejecucción, sólo en comentario.
